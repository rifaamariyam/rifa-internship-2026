# %%
print("hello,jupyter!")
# Out:
# hello,jupyter!

# %%
sensor={
    "temperature":24.5,
    "humidity":87,
    "co2":950,
}
print(f"temperature:{sensor['temperature']}c")
print(f"humidity:{sensor['humidity']}%")
print(f"co2:{sensor['co2']}ppm")
# Out:
# temperature:24.5c
# humidity:87%
# co2:950ppm
